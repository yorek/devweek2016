# %%
library("AzureML")
ws <- workspace()
dat <- download.datasets(ws, "UCI Iris Dataset")

# %%
head(dat)
# Out:
#   sepal.length.in.cm sepal.width.in.cm petal.length.in.cm petal.width.in.cm
# 1                5.1               3.5                1.4               0.2
# 2                4.9               3.0                1.4               0.2
# 3                4.7               3.2                1.3               0.2
# 4                4.6               3.1                1.5               0.2
# 5                5.0               3.6                1.4               0.2
# 6                5.4               3.9                1.7               0.4
#         class
# 1 Iris-setosa
# 2 Iris-setosa
# 3 Iris-setosa
# 4 Iris-setosa
# 5 Iris-setosa
# 6 Iris-setosa

# %%
library(GGally)

# %%
# define a function to calculate Pearson Coefficient
panel.pearson = function(x, y, ...) 
{
  horizontal = (par("usr")[1] + par("usr")[2]) / 2; 
  vertical = (par("usr")[3] + par("usr")[4]) / 2; 
  text(horizontal, vertical, format(abs(cor(x,y,method="pearson")), digits=2)) 
}

# %%
dat$factorClass = unclass(as.factor(dat$class))]

# %%
dat$colorClass = c("red", "green", "blue")[dat$factorClass]

# %%
head(dat)
# Out:
#   sepal.length.in.cm sepal.width.in.cm petal.length.in.cm petal.width.in.cm
# 1                5.1               3.5                1.4               0.2
# 2                4.9               3.0                1.4               0.2
# 3                4.7               3.2                1.3               0.2
# 4                4.6               3.1                1.5               0.2
# 5                5.0               3.6                1.4               0.2
# 6                5.4               3.9                1.7               0.4
#         class factorClass colorClass
# 1 Iris-setosa           1        red
# 2 Iris-setosa           1        red
# 3 Iris-setosa           1        red
# 4 Iris-setosa           1        red
# 5 Iris-setosa           1        red
# 6 Iris-setosa           1        red

# %%
unique(dat[5:7])
# Out:
#               class factorClass colorClass
# 1       Iris-setosa           1        red
# 51  Iris-versicolor           2      green
# 101  Iris-virginica           3       blue

# %%
plot(dat[1:4], bg=dat$colorClass, pch=21, upper.panel=panel.pearson)

# %%
ggpairs(data=dat, columns=1:4, upper=list(continuous="density"), colour="class")
